# %%
# !pip install gdown lightning transformers

# %% [markdown]
# # Download the zip file

# %%
# !gdown https://drive.google.com/uc?id=1fZG_-FwADGMI_TqbPaA8z10ZMGPvb_vG
# !unzip -q data.zip
# !mv an2dl2526c2v2 data
# !ls -l data

# %%
import shutil
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import torch
from PIL import Image
from tqdm import tqdm
from transformers import CLIPModel, CLIPProcessor

# %%
IMG_DIR = Path("data/train_data")
TRASH_DIR = Path("data/junk_images")
BATCH_SIZE = 32

# %%
MODEL_ID = "openai/clip-vit-large-patch14"

# %%
def setup_directories():
    """Ensures directories exist and cleans previous trash if needed."""
    if not IMG_DIR.exists():
        raise FileNotFoundError(f"Image directory {IMG_DIR} not found.")

    TRASH_DIR.mkdir(parents=True, exist_ok=True)
    print(f"Working with images in: {IMG_DIR}")
    print(f"Trash bin located at: {TRASH_DIR}")

# %%
def is_suspicious_color(img):
    """
    H&E tissue is Pink/Purple.
    Orcs and Slimes are often Green, Blue, or dark Grey.
    Returns True if the image has 'illegal' colors for histology.
    """
    # Convert to HSV (Hue, Saturation, Value)
    img_hsv = img.convert("HSV")
    h, s, v = img_hsv.split()
    h_arr = np.array(h)
    s_arr = np.array(s)

    # 1. Check for GREEN/BLUE (Hue between 40 and 180 out of 255 in PIL)
    # H&E is usually Purple (Hue ~200-240) or Pink (Hue ~240-10)
    green_blue_pixels = np.sum((h_arr > 35) & (h_arr < 180) & (s_arr > 20))
    total_pixels = h_arr.size

    if (green_blue_pixels / total_pixels) > 0.05:  # >5% green/blue
        return True, "Contains Green/Blue (Orc/Slime color)"

    return False, ""

# %%
def get_clip_model():
    """Loads the CLIP model and processor."""
    print(f"Loading {MODEL_ID}...")
    device = "cuda" if torch.cuda.is_available() else "cpu"
    # mps for Mac users, usually not needed for Colab but good practice
    if torch.backends.mps.is_available():
        device = "mps"

    model = CLIPModel.from_pretrained(MODEL_ID).to(device)
    processor = CLIPProcessor.from_pretrained(MODEL_ID)
    model.eval()
    return model, processor, device

# %%
def filter_junk_aggressive(confidence_threshold=0.85):
    print("Loading Aggressive CLIP Filter...")
    model_id = "openai/clip-vit-large-patch14"
    model = CLIPModel.from_pretrained(model_id).to(
        "cuda" if torch.cuda.is_available() else "cpu"
    )
    processor = CLIPProcessor.from_pretrained(model_id)
    model.eval()

    # 1. Define 'True' vs 'Junk' Prompts
    # We use a dictionary to track *what* kind of junk we found
    prompts = {
        "tissue": "a microscope image of H&E stained pink and purple histology tissue",
        "junk_fantasy": "a digital illustration of a fantasy character, orc, goblin, or monster",
        "junk_game": "a video game screenshot, pixel art, or user interface",
        "junk_slime": "a green or blue slime monster, gelatinous blob",
        "junk_sketch": "a pencil sketch, drawing, or cartoon",
        "junk_noise": "blurry static noise or corrupted image",
    }

    # Extract keys and text for processing
    prompt_keys = list(prompts.keys())
    prompt_texts = list(prompts.values())

    print("Encoding prompts...")
    inputs = processor(text=prompt_texts, return_tensors="pt", padding=True).to(
        model.device
    )

    all_images = list(IMG_DIR.glob("*.png")) + list(IMG_DIR.glob("*.jpg"))
    print(f"Scanning {len(all_images)} images...")

    trash_count = 0
    reasons = {}

    for p in tqdm(all_images):
        try:
            img = Image.open(p).convert("RGB")

            # --- LAYER 1: Color Check (Fast & Strict) ---
            is_suspicious, color_reason = is_suspicious_color(img)
            if is_suspicious:
                shutil.move(str(p), str(TRASH_DIR / p.name))
                trash_count += 1
                reasons[p.name] = color_reason
                continue  # Skip CLIP if color check failed

            # --- LAYER 2: CLIP Classification ---
            img_input = processor(images=img, return_tensors="pt").to(model.device)
            with torch.no_grad():
                outputs = model(
                    input_ids=inputs.input_ids, pixel_values=img_input.pixel_values
                )
                probs = outputs.logits_per_image.softmax(dim=1).cpu().numpy()[0]

            tissue_score = probs[0]
            junk_score = np.max(probs[1:])
            junk_idx = np.argmax(probs[1:]) + 1

            # --- LAYER 3: Thresholding ---
            # Condition A: It looks more like junk than tissue
            if junk_score > tissue_score:
                move_file = True
                reason = f"Detected: {prompt_keys[junk_idx]} ({junk_score:.2f})"

            # Condition B: It looks like tissue, but NOT SURE ENOUGH (< 85%)
            elif tissue_score < confidence_threshold:
                move_file = True
                reason = f"Low Confidence Tissue ({tissue_score:.2f} < {confidence_threshold})"
            else:
                move_file = False

            if move_file:
                shutil.move(str(p), str(TRASH_DIR / p.name))
                trash_count += 1
                reasons[p.name] = reason

                # Move mask if exists
                mask_p = IMG_DIR / f"mask_{p.name}"
                if mask_p.exists():
                    shutil.move(str(mask_p), str(TRASH_DIR / mask_p.name))

        except Exception as e:
            print(f"Error on {p.name}: {e}")

    print(f"Moved {trash_count} images to trash.")
    return reasons

# %%
reasons = filter_junk_aggressive()

# %%
# Visualize the results with reasons
def show_aggressive_trash():
    trash_images = list(TRASH_DIR.glob("*.jpg")) + list(TRASH_DIR.glob("*.png"))
    # Filter out masks for display
    trash_images = [f for f in trash_images if not f.name.startswith("mask_")]

    if not trash_images:
        print("No trash found.")
        return

    # Show top 15
    num_show = min(15, len(trash_images))
    fig, axes = plt.subplots(3, 5, figsize=(15, 9))
    axes = axes.flatten()

    for i in range(num_show):
        p = trash_images[i]
        img = Image.open(p)
        axes[i].imshow(img)
        axes[i].axis("off")
        # specific reason or default
        r = reasons.get(p.name, "Unknown")
        axes[i].set_title(f"{r}", fontsize=8)

    plt.tight_layout()
    plt.show()


show_aggressive_trash()

# %%
remaining_files = list(IMG_DIR.glob("*.jpg")) + list(IMG_DIR.glob("*.png"))
print(f"Remaining images in train folder: {len(remaining_files)}")

# %%
# Get the trash image paths
trash_image_paths = [
    f
    for f in TRASH_DIR.iterdir()
    if f.suffix.lower() in [".png", ".jpg", ".jpeg"] and not f.name.startswith("mask_")
]
print(trash_image_paths)

# %%
len(trash_image_paths)
